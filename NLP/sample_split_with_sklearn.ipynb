# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Jack\Downloads\servings.csv")

# %%
df["Category"] = df["Category"].fillna("Miscellaneous")

# %%
from sklearn.model_selection import train_test_split

# Stratified sampling using train_test_split
df_sampled, _ = train_test_split(df, train_size=2000, stratify=df["Category"])

# %%
df_sampled.sample(5)
# Out:
#              Day                                          Food Name  \
# 4637  2024-01-19        Kallo, Lentil and Pea Veggie Cake, Beetroot
# 2476  2023-10-28        Chicken Breast, Skin Removed Before Cooking
# 2411  2023-10-25  Kallo, Organic Wholegrain Rice Cakes, Lightly ...
# 920   2023-08-13                   Onion, White, Yellow or Red, Raw
# 5301  2024-02-12                          Tofuking, Five Spice Tofu
#
#                 Amount  Energy (kcal)  Alcohol (g)  Caffeine (mg)  Water (g)  \
# 4637  3.00 Veggie Cake         120.00          NaN            NaN        NaN
# 2476          371.00 g         641.83          0.0            0.0     240.26
# 2411    7.00 rice cake         195.56          0.0            NaN        NaN
# 920            62.00 g          24.80          0.0            0.0      55.25
# 5301          131.00 g         272.48          NaN            NaN        NaN
#
#       B1 (Thiamine) (mg)  B2 (Riboflavin) (mg)  B3 (Niacin) (mg)  ...  \
# ...
